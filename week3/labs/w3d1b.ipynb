# %% [markdown]
# ![Reminder to Save](https://github.com/jamcoders/jamcoders-public-2023/blob/main/images/warning.png?raw=true)

# %%
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
    # !eval "$(echo "cGlwIGluc3RhbGwgLS1mb3JjZS1yZWluc3RhbGwgZ2l0K2h0dHBzOi8vZ2l0aHViLmNvbS9qYW1jb2RlcnMvamFtY29kZXJzLXB1YmxpYy0yMDI0LmdpdCAtLXF1aWV0Cg==" | base64 -d)"
from jamcoders.base_utils import *

# %% [markdown]
# # Week 3 Day 1B: Introducing Recursion

# %% [markdown]
# ## Question 0: Definitions and Examples
#
# Let's start from the building blocks!

# %% [markdown]
# What is recursion? Answer in words.

# %%
# Answer here!

# %% [markdown]
# What is a base case?

# %%
# Answer here!

# %% [markdown]
# What is a recursive case?

# %%
# Answer here!

# %% [markdown]
# ## Question 1: List slicing and warm up
#
# In recursion, we often have to split the inputs into different parts.
#
# For example, sometimes we might break the input in half and call the function on both halves. Sometimes we might break the input to handle the first thing, and then recursively call the function on the rest of the input.
#
# So, we will practice slicing.
#
# *Note: `pass` does not do anything. Delete it when you add your code.*

# %% [markdown]
# ### Question 1.1
#
# Write a function to return the first element of a list

# %%
def first_element(lst):
    """
    Args:
        lst (list(object)):
            A list of objects.

    Returns (object):
        The first element of lst. If the list is empty, return the empty list.
    """
    # Your code here!
    pass

# Use your function here to test that it returns the first element of the list.

# %% [markdown]
# ### Question 1.2
#
# Write a function to return everything **except** the first element of a list

# %%
def except_first(lst):
    """
    Args:
        lst (list(object)):
            A list of objects.

    Returns (list(object)):
       A copy of lst with the first element removed. If the list has length < 2, return the empty list.
    """
    # Your code here!
    pass

# Use your function here to test that it returns everything except the first element of the list.

# %% [markdown]
# ### Question 1.3
#
# Write a function to return everything in the first half of the list. If there are an odd number of items in the list, make the first half contain one less element than the second half.
#
# For example, for the list `[1, 2, 3, 4, 5, 6, 7]`, the first half should return `[1, 2, 3]`

# %%
def first_half(lst):
    """
    Args:
        lst (list(object)):
            A list of objects.

    Returns (list(object)):
       A list containing the first half of lst. If the length of lst is an odd number (2k+1),
       the output will contain the first k items in lst.
    """
    # Your code here!
    pass

# Use your function here to test that the function returns the first half of the list

# %% [markdown]
# ### Question 1.4
#
# Write a function to return everything in the second half of the list. If there are an odd number of items in the list, make the first half contain one less element than the second half.
#
# For example, for the list `[1, 2, 3, 4, 5, 6, 7]`, the second half should return `[4, 5, 6, 7]`

# %%
def second_half(lst):
    """
    Args:
        lst (list(object)):
            A list of objects.

    Returns (list(object)):
       A list containing the second half of lst. If the length of lst is an odd number (2k+1),
       the output will contain the last k+1 items in lst.
    """
    #Your code here!
    pass

# Use your function here to test that the function returns the second half of the list

# %% [markdown]
# Modify your code if needed, or verify that your code for `first_element()`, `except_first()`, `first_half()`, `second_half()` also work for strings! Running the following cell will test this.

# %%
test_list = [1,2,3,4,5]
assert_equal([1], first_element(test_list))
assert_equal([2,3,4,5], except_first(test_list))
assert_equal([1,2], first_half(test_list))
assert_equal([3,4,5], second_half(test_list))

test_string = "jam_coders"
assert_equal("j", first_element(test_string))
assert_equal("am_coders", except_first(test_string))
assert_equal("jam_c", first_half(test_string))
assert_equal("oders", second_half(test_string))

# %% [markdown]
# ## Question 2: Starting Recursion
#
# Ok, now that we have some of the building blocks down, let's get started with trying recursion!
#
# Remember that **recursion** is a programming technique where the function calls itself using modified inputs. The result of that function call is used and potentially modified in some way to form the correct output.
#
# We have 2 cases in the recursive function:
# 1. The base case: a situation where we can return the result of the function without using recursive calls. This is the simplest solution to the problem.
# 2. The recursive case: performing a function call to the same function using modified arguments. The problem is broken down into smaller subproblems, moving us closer to the base case.
#
# One thing you'll hear us say very often is **trust the recursion**. You must have faith that the base case, combined with the way you break the problem down with recursion, will correctly solve your question!!
#
# > Side note: You may think that most of the examples you have seen of recursion can be easily replaced with different code, like for loops. However, many times recursion is more natural. We are doing this example in preparation for other lectures and exercises to come!

# %% [markdown]
# ### Summing Numbers with Recursion
#
# For example, let's try to calculate the sum of all numbers from `1` to `n` with recursion. (Yes, we can do this with a `for` loop, but let's practice recursion so that we can use it for harder problems as well)
#
# __Base Case__
#
# Let's start with the base case, or the simplest version of the problem. This is a situation in which we know the answer.
#
# The simplest solution for the sum of numbers from  `1` to `n` is if `n == 1`. In this situation, the answer is just `1`!
#
# __Recursive Case__
#
# Now, the recursive case. Let's say `n != 1`. How do we break down the problem to solve this?
#
# Let's start with `n == 2`, for example. The solution to this is `2`, plus the sum of all of the numbers up until 2 (so this function itself, called on the number before 2 which is 1). That hits the base case of `1`, which returns and gets us the final solution!
#
# __Code__
# ```python
# def sum_one_to_n(n):
#     # Base Case
#     if n == 1:
#         return 1
#     # Recursive case
#     else:
#         # We return the current number added to the sum up until the previous number
#         # This is where we trust the recursion. We trust that sum_one_to_n(n - 1) will do what we believe it should do.
#         return n + sum_one_to_n(n - 1)
# ```

# %% [markdown]
# ### Question 2.1: Factorial
#
# It's time to try this yourself! Implement `factorial(n)` below. Remember that a factorial is very similar to a sum, but instead of adding, you are multiplying numbers together.
#
# **Reminder:** The factorial of a number `n` is the product of all the numbers from 1 up to and including n. For example, `factorial(3)` = 3 * 2 * 1 = 6.

# %%
def factorial(n):
    """
    Args:
        n (int):
            A non-negative integer.

    Returns (int):
       The factorial of n.
    """
    # Your code here!

assert_equal(1, factorial(1))
assert_equal(2, factorial(2))
assert_equal(6, factorial(3))
assert_equal(24, factorial(4))
assert_equal(720, factorial(6))
assert_equal(3628800, factorial(10))

# %% [markdown]
# ## Question 3: The Fibonacci Sequence
#
# It's time for one of the most classic problems in recursion: the Fibonacci Sequence! Trying to solve this with a loop will be much more challenging, so we're going to use recursion instead.
#
# **Fibonacci numbers** have many applications in nature and math. Here are the first 10 Fibonacci numbers:
#
# ```
# fib(0) == 0
# fib(1) == 1
# fib(2) == 1
# fib(3) == 2
# fib(4) == 3
# fib(5) == 5
# fib(6) == 8
# fib(7) == 13
# fib(8) == 21
# fib(9) == 34
# ...
# ```
#
# Can you see a pattern? Using math, we can define the $n^{th}$ Fibonacci  number, $\operatorname{fib}(n)$ as follows:
#
# **Base case $-$ if $n \leq 1$:**
#
# > $\operatorname{fib}(0) = 0$
# >
# > $\operatorname{fib}(1) = 1$
#
# **Recursive case $-$ if $n > 1$:**
#
# > $\operatorname{fib}(n) = \operatorname{fib}(n - 1) + \operatorname{fib}(n - 2)$
#
#
# Write code to find the $n^{th}$ Fibonacci number.

# %%
def fib(n):
    """
    Args:
      n (int): A non-negative number

    Returns (int):
      The n-th Fibonacci number, Fib(n)
    """
    # YOUR CODE HERE
    pass


# When you finish, these should all pass
assert_equal(want=0, got=fib(0))
assert_equal(want=1, got=fib(1))
assert_equal(want=1, got=fib(2))
assert_equal(want=2, got=fib(3))
assert_equal(want=8, got=fib(6))
assert_equal(want=34, got=fib(9))
assert_equal(want=6765, got=fib(20))

# %% [markdown]
# ## Question 4: Boolean Recursion
#
# Often, we see recursive functions that return `list`s or `int`s or `float`s or `string`s. However, sometimes we see recursions that return `boolean` values!

# %% [markdown]
# In this question, we will **use recursion** to write a function called `is_in(lst, item)` that takes in a list called `lst` and returns `True` if the `item` is in the `lst`, and `False` otherwise

# %% [markdown]
# There are many ways to write this function, but let's do it recursively. For the first base case, should we return `True` or `False` if `lst` is empty?

# %%
# Answer in words, and write the if statement in code

# %% [markdown]
# For the second base case, should we return `True` or `False` if the first element `lst[0] == item`?

# %%
# Answer in words, and write the if statement in code

# %% [markdown]
# For the recursive case, suppose that we know that the first element is not the item. How can we call `is_in(lst, item)` to check the remainder of the list, excluding the first element that we already know is not the item?
#
# In other words, we already know the first element is not the item we're looking for. So, we can call `is_in()` using the `lst` without the first element, searching for the same item as before. This way, the list that we're searching gets one element shorter.

# %%
# Answer in words, and write the recursive call is_in() in code

# %% [markdown]
# Now we are ready to write the function!
#
# > Note: This question heavily relies on the list slicing from question 1, and you may use your previous functions if you'd like. These functions include: `first_element()`, `except_first()`, `first_half()`, `second_half()`.

# %%
def is_in(lst, item):
    """
    Args:
        lst (list(object)): A list of objects to seach in.
        item (object): An item to search for.

    Returns (bool):
        Whether item is in lst.
    """

    # ===First base case===: If the list has length zero, we return False.
    if #FILL ME IN:
        return False

    first_item = # Get the first item

    # ===Second base case===: If the first thing in the list is the item we are searching for, we return True.
    if #FILL ME IN:
        return True

    rest_of_list = # Get the rest of the list

    # ===Recursive case===: We search for the item in the rest of the list
    return #is_in(FILL ME IN)

assert_equal(True, is_in([1, 2, 3], 3))
assert_equal(True, is_in(['j', 'c', 22], 'c'))
assert_equal(False, is_in(['r', 2, 'hello'], 'bye'))

# %% [markdown]
# **Challenge $-$ Optional**
#
# The rest of the question is a challenge problem. For the next part of the question, Liam wants to write `is_in2(lst, item)` that does the same thing as `is_in(lst, item)`, except it follows a different logic:
#   * if the length of the `lst` is `0`, return `False` because `item` is not in an empty list.
#   * if the length of the `lst` is `1` and the element is `item` (In otherwords, `lst[0] == item`), then we have found the element and `return True`.
#   * call `is_in2()` on the first half of `lst`, keep track of the `return` boolean value.
#   * call `is_in2()` on the second half of `lst`, keep track of the `return` boolean value.
#   * return `True` if the value is either in the first half of `lst` or the second half of `lst`, and `False` otherwise.

# %% [markdown]
# Explain in words why the logic above makes sense. This is the most important part of the question, so please ask us to explain this recursion to you before you move on if you are not sure!

# %%
# Write your answer in words here!

# %% [markdown]
# In words, what are the base cases and recursive case?

# %%
# Write your answer in words here!

# %% [markdown]
# Now code `is_in2(lst, item)`

# %%
def is_in2(lst, item):
    """
    Args:
        lst (list(object)): A list of objects to seach in.
        item (object): An item to search for.

    Returns (bool):
        Whether item is in lst.
    """
    # Your code here!

    # A summary of the key steps:
    # 1. handle the empty list
    # 2. handle the list with a single element
    # 3. split the list into two halves (we have already handled the case of an empty list)
    # 4. return True if the item is either in the left, OR in the right!

    pass

# Test your code here!
assert_equal(True, is_in2([1, 2, 3], 3))
assert_equal(True, is_in2(['j', 'c', 22], 'c'))
assert_equal(False, is_in2(['r', 2, 'hello'], 'bye'))

# %% [markdown]
# ## Question 5: Ping Pong
#
# Anita and James like playing ping pong together. Let's write functions to play ping pong!

# %% [markdown]
# ### Question 5.1
#
# Help Anita write a function called `ping(n)`:
#   * if `n == 0`, then `return`.
#   * If `n > 0`: `ping(n)` should `print('ping')` then call `pong(n - 1)`.
#   * you haven't written `pong()` yet, but we will write that next!

# %%
def ping(n):
    """
    Args:
        n (int): Number of ping-pong steps to make.

    Returns:
        None
    """
    # If n == 0, return
    # Otherwise:
    #   print 'ping'
    #   call pong(n - 1)
    pass

# %% [markdown]
# Help James write a function called `pong(n)`:
# * if `n == 0`, then `return`.
# * `pong(n)` should `print('pong')` then call `ping(n - 1)`.
# * you have already written `ping()`!
#
# **Warning: If you call both `ping(n)` and `pong(n)`, you will go into an infinite loop. Make sure you are calling `ping(n - 1)` and `pong(n - 1)`. You will also go into an infinite loop if you forget the base case**

# %%
def pong(n):
    """
    Args:
        n (int): Number of ping-pong steps to make.

    Returns:
        None
    """
    # If n == 0, return
    # Otherwise:
    #   print 'pong'
    #   call ping(n - 1)
    pass

# %% [markdown]
# Try running `ping(5)`. Can you explain what happens and why?

# %%
# run ping(5). What happens, and why?

# %% [markdown]
# What are the base and recursive cases?

# %%
# explain the base and recursive cases in words

# %% [markdown]
# **This may be confusing, so the rest of this problem is optional.**
#
# Tarun watches them play, and notices that he knows how long the game will last just by looking at `n`. He thinks this is bad because there is no skill involved. So, he writes a function called `is_success(n)` that will return `True` with `n` percent chance.
#
# Run his code a few times to understand how `is_success(n)` works. Notice that you will get different results every time you run it.

# %%
# Run this a few times to understand how is_success(n) works
from random import randrange

# Here is Tarun's code
def is_success(n):
    """
    Args:
        n (int): An integer between 0 and 100.

    Returns (bool):
        With probability n/100, returns True. Otherwise, returns False.
    """
    return randrange(100) < n

# Here is how you could use it.
print(is_success(0))
print(is_success(30))
print(is_success(40))
print(is_success(50))
print(is_success(60))
print(is_success(70))
print(is_success(100))

# %% [markdown]
# Create `ping_skillz(p, q)` and `pong_skillz(p, q)`. Use `is_success` so that with `n` percent chance, they call the other function.
#
# For `ping_skillz(p, q)`:
#   * with `p` percent chance: print `'ping!'` and call `pong(p, q)`
#   * with `100 - p` percent chance: print `'ping failed'` and `return`
#
# For `pong_skillz(p, q)`:
#   * with `q` percent chance: print `'pong!'` and call `ping(p, q)`
#   * with `100 - q` percent chance: print `'pong failed'` and `return`

# %%
def ping_skillz(p, q):
    """
    Args:
        p (int): The probability of success of ping_skillz. This is an integer between 0 and 100.
        q (int): The probability of success of pong_skillz. This is an integer between 0 and 100.

    Returns:
        None.
    """
    # Code here! Remember to use is_success to check if we successfully went to pong() or not!
    pass

def pong_skillz(p, q):
    """
    Args:
        p (int): The probability of success of ping_skillz. This is an integer between 0 and 100.
        q (int): The probability of success of pong_skillz. This is an integer between 0 and 100.

    Returns:
        None.
    """
    # Code here! Remember to use is_success to check if we sucessfully went to ping() or not!
    pass

# Test your code here!

# %% [markdown]
# **Very, very optional**
#
# Run `ping_skillz(50, 50)` ten times, recording the average number of combined `ping!`s and `pong!`s. On average, how many combined `ping!`s and `pong!`s are printed out?
#
# *You can manually run it 10 times and calculate the sum (which we recommend), or you can write a function to help if you have extra time.*

# %%
# Your answer for the average number. Feel free to show your calculation eg:
# print( (1 + 0 + 2 + 0 ... ) / 10 )

# %% [markdown]
# **Very, very, very optional**
#
# The following is extremely challenging brain teaser that you should save for the end of the lab and attempt only if you have time.
#
# Can you use math to reason about why you got the answer above? That is, if `p == q == 0.5`, how many combined `ping!`s and `pong!`s would you expect to see printed on average?

# %%
# Explain your reasoning and any math you used

# %% [markdown]
# ## Question 6: Palindrome Revisited
#
# Recall we had an entire lecture on palindromes. You may have noticed that a palindrome is like an onion. You may think that is because they both stink. But there is yet another similarity: you can peel the palindrome layer by layer.
#
# For example: Suppose you wanted to check if `'racecar'` is a palindrome. You could look at the first and last letter, and if they are the same, recursively check the rest of the string to see if `'aceca'` is a palindrome.  You could keep on peeling away the first and last letters layer by layer until you have a single letter `e`, which is a palindrome.
#
# Just as we have done before, brainstorm the logic of the function below

# %%
# What are the base cases?

# What are the recursive cases?

# Write some tentative logic for how the code will work in words

# %% [markdown]
# Try to code the recursive function `is_palindrome(string)` that returns `True` if `string` is a palindrome, and `False` otherwise. Make sure it works for both even and odd length `string`s.

# %%
def is_palindrome(string):
    """
    Args
      string (str): A string.

    Returns (bool):
      Whether string is a palindrome.
    """
    # Your code here

    # What is the base case?

    # What is the recursive case?
    pass

print(is_palindrome("") == True)
print(is_palindrome("racecar") == True)
print(is_palindrome("raccar") == True)
print(is_palindrome(
    "Madam Im Adam".lower().replace(" ", "")
) == True)
print(is_palindrome("Eve".lower()) == True)
print(is_palindrome("racYXYXcar") == False)
print(is_palindrome("racXYXYXXzYXYXczar") == False)
