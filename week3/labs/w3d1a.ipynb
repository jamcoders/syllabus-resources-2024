# %% [markdown]
# ![Reminder to Save](https://github.com/jamcoders/jamcoders-public-2023/blob/main/images/warning.png?raw=true)

# %%
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
    # !eval "$(echo "cGlwIGluc3RhbGwgLS1mb3JjZS1yZWluc3RhbGwgZ2l0K2h0dHBzOi8vZ2l0aHViLmNvbS9qYW1jb2RlcnMvamFtY29kZXJzLXB1YmxpYy0yMDI0LmdpdCAtLXF1aWV0Cg==" | base64 -d)"
from jamcoders.base_utils import *
from jamcoders.week2.lab8a import *

# %% [markdown]
# # Week 3, Day 1, Lab A: Tracing Code

# %% [markdown]
# ## Question 1: Predicting Python
#
# We can always run Python code to see what it does, but it's often very helpful to know what it will do just by reading it.
#
# For the following questions, you should read the Python code and determine what will happen *without running the code*.

# %% [markdown]
# ### 1.1: Arithmetic

# %% [markdown]
# What will `x` be equal to after this code is finished running?
#
# Hint: You should write down your intermediate steps on paper.
# ```python
# x = 7
# y = 3
# z = 10
# y = z + x - y
# z *= 5
# z %= y
# x -= 3
# x = (z - x) * (y - 7)
# x = 1 - x
# ```

# %%
# Enter your answer here
# Give your answer as an integer
answer1a =

# This code checks for correctness. Do not modify it.
check_answer1(answer1a)

# %% [markdown]
# ### 1.2: Conditionals
#
# There is one code box at the bottom of 1.2 to enter all your answers for this section in.

# %% [markdown]
# (a) What will the following code print when `a = 1` and `b = 2`?
# ```python
# if a < b:
#     print("a")
# else:
#     print("b")
# ```

# %% [markdown]
# (b) What about this code? Again with `a = 1` and `b = 2`.
# ```python
# if a < b:
#     print(a)
# else:
#     print(b)
# ```

# %% [markdown]
# (c) What will this code print when `L = [1, 3, 5, 7]` and `x = 5`?
# ```python
# if L[1] == x:
#     print("x is in L")
# else:
#     print("x is not in L")
# ```

# %%
# Enter your answers here
# Give all answers for 1.2 as strings.
# ❗❗ IMPORTANT: If a number is printed, put it in a string, e.g., "3"
answer2a =
answer2b =
answer2c =

# This code checks for correctness. Do not modify it.
check_answer2(answer2a, answer2b, answer2c)

# %% [markdown]
# ### 1.3: Loops

# %% [markdown]
# (a) What will the following code print when `L = [1, 3, 5, 7]` and `x = 5`?
# ```python
# for item in L:
#     if x == item:
#         print("x is in L")
#     else:
#         print("x is not in L")
#     break
# ```

# %% [markdown]
# (b) What will the following code print when `L = [1, 3, 5, 7]` and `x = 5`?
# ```python
# found = False
# for item in L:
#     if x == item:
#         print("x is in L")
#         found = True
#         break
# if not found:
#     print("x is not in L")
# ```

# %% [markdown]
# (c) What will the value of `orr` be after this code finishes running?
# ```python
# orr = 0
# while True:
#     if orr - 9000 > 0:
#         break
#     orr += 2
# ```
#
# (d) How many times will `*` be printed by this code?
# ```python
# for i in range(10):
#     for j in range(10):
#         for k in range(20):
#             print('*')
# ```

# %%
# Enter your answers here
# Give answers for (a) and (b) as strings:
answer3a =
answer3b =

# Give answers for (c) and (d) as integers:
answer3c =
answer3d =

# This code checks for correctness. Do not modify it.
check_answer3(answer3a, answer3b, answer3c, answer3d)

# %% [markdown]
# ### 1.4: Functions

# %% [markdown]
# (a) What will the following code print?
# ```python
# def f1(x):
#     return 5
#
# print(f1(100))
# ```
#
# (b) What about this code?
# ```python
# def f2(x, y, z):
#     return x + y + z
#
# print(f2(1, 6, 10))
# ```
#
# (c) What will this print?
# ```python
# def f3(x, y, z):
#     return x * y + z
#
# def f4(x):
#     return f3(x, 2*x, 3*x)
#
# print(f4(2))
# ```
#
# (d) What will this code print?
# ```python
# def sum_first_evens(x):
#     out = 0
#     i = 1
#     while i < x:
#         out += i
#         i += 2
#     return out
#
# print(sum_first_evens(7))
# ```

# %%
# Enter your answers here
# Give all answers for 1.4 as integers.
answer4a =
answer4b =
answer4c =
answer4d =

# This code checks for correctness. Do not modify it.
check_answer4(answer4a, answer4b, answer4c, answer4d, 120)

# %% [markdown]
# ## Question 2: Review of If Statements and Loops

# %% [markdown]
# ### 2.1: Data Recovery
#
# Tarun has two favorite numbers - he calls them `a` and `b`. Yesterday, he calculated their average as `c = (a + b) / 2`. But now disaster has struck! Tarun forgot what `b` is. Thankfully, he still remembers the values of `a` and `c`.
#
# Write a function `data_recovery(a, c)` that take in `a` and `c`, and return the missing number `b`. i.e., `data_recovery(a, c)` should return a number `b` such that `c = (a + b) / 2`.

# %%
def data_recovery(a, c):
    # YOUR CODE HERE
    return


assert_equal(got=data_recovery(11, 15), want=19)
assert_equal(got=data_recovery(4, 3), want=2)

# %% [markdown]
# ### 2.2: Quadrant Selection
#
# Given two non-zero numbers `x` and `y`, we can plot them on a plane:
#
# ![](https://open.kattis.com/problems/quadrant/file/statement/en/img-0001.png)
#
# As in the picture, any such point is either in quadrant 1, 2, 3, or 4.
#
# Write a function `quadrant(x, y)` that returns the number of the quadrant that the point `(x, y)` is in.
#
# Note: `(x, y)` is guaranteed to lie strictly in exactly one quadrant because `x` and `y` are non-zero.

# %%
def quadrant(x, y):
    # YOUR CODE HERE
    return


assert_equal(got=quadrant(10, 6), want=1)
assert_equal(got=quadrant(-12, 5), want=2)
assert_equal(got=quadrant(-1, -30), want=3)
assert_equal(got=quadrant(9, -13), want=4)

# %% [markdown]
# ### 2.3 Freezing Days
#
# In Jamaica, the temperature is never freezing (less than or equal to 0 degrees). But it's much colder in Canada: almost every day in the winter is freezing.
#
# James has a list of temperatures he recorded over the last few days and wants to know how many days from this list were freezing. Can you help him?
#
# Write a function `num_freezing_days(L)` that takes a list `L` containing integers and returns how many are freezing (less than or equal to zero).

# %%
def num_freezing_days(L):
    # YOUR CODE HERE
    return


assert_equal(got=num_freezing_days([5, -10, 15]), want=1)
assert_equal(got=num_freezing_days([-14, -5, -39, -5, -7]), want=5)

# %% [markdown]
# ### 2.4 Beach Day! 🌴
#
# Anita has a packing list that she created for her trip to Ocho Rios! Her list is defined in the variable `packing_list`:
# ```python
# packing_list = [
#     ['shirts', 'tank tops', 'shorts', 'dresses'],
#     ['swimsuit', 'sunblock', 'sunglasses'],
#     ['shampoo', 'lotion', 'body wash'],
#     ['sneakers', 'sandals']
# ]
# ```
#
# Notice that `packing_list` is a **list of lists**, with each **sublist** related to a category that is stored in `list_category`.
#
# ```python
# list_category = ['Clothes: ', 'Swimming gear: ', 'Body care: ', 'Shoes: ']
# ```
#
# <br>
#
# She printed the list to show her friends who don't know Python, and they got scared after seeing the nested list! ( ⚆ _ ⚆ )
#
# Can you help her print the list so that it looks like normal text? Define the function `print_packing_list(packing_list, list_category)` so that it prints:
#
# ```
# Clothes: shirts, tank tops, shorts, dresses
# Swimming gear: swimsuit, sunblock, sunglasses
# Body care: shampoo, lotion, body wash
# Shoes: sneakers, sandals
# ```
#
# **Hints**:
# - Notice that `list_category[i]` corresponds to the category of the items in `packing_list[i]`. For example, `list_category[1]` is `Swimming gear` and all of the items in `packing_list[1]` are swimming gear items (`['swimsuit', 'sunblock', 'sunglasses']`)
# - In order to make the list look pretty, you'll have to do some string operations. For example:
#
#     ```python
#     item1 = "apple"
#     item2 = "banana"
#     print(item1 + ", " + item2)
#     ```
#     will print `apple, banana`
# - You should use nested for loops for this question!

# %%
def print_packing_list(packing_list, list_category):
    # YOUR CODE HERE
    return

# The following code will call the function so you can check if your print statement is correct
print_packing_list(
    [
    ['shirts', 'tank tops', 'shorts', 'dresses'],
    ['swimsuit', 'sunblock', 'sunglasses'],
    ['shampoo', 'lotion', 'body wash'],
    ['sneakers', 'sandals']
], ['Clothes: ', 'Swimming gear: ', 'Body care: ', 'Shoes: ']
)
