# %%
# Always run this code.
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
    # !eval "$(echo "cGlwIGluc3RhbGwgLS1mb3JjZS1yZWluc3RhbGwgZ2l0K2h0dHBzOi8vZ2l0aHViLmNvbS9qYW1jb2RlcnMvamFtY29kZXJzLXB1YmxpYy0yMDI0LmdpdCAtLXF1aWV0Cg==" | base64 -d)"
from jamcoders.base_utils import *
NotebookTracking.set_activation(True)

# %% [markdown]
# # Additional Review

# %% [markdown]
# # 0. Tracing

# %% [markdown]
# Tracing is fundamental for understanding what code is going to do, and a prerequisite for writing code correctly without being able to run it (as you have to do in an exam).
#
# Not to say that this will be the case in the final exam (I haven't seen it yet), but on the exam last Friday there were about ~55 points out of 115 that could have been gotten just by being good at tracing.
#
# ---
#
# **HOW TO LEARN EFFECTIVELY WITH THESE TRACING QUESTIONS:**
#
# For all tracing questions, I'd recommend:
# 1. Going through the code line by line, and writing out what the value of each variable will be at each line (as pytutor would do).
# 2. Copy paste the code into [pytutor](https://pythontutor.com/python-debugger.html#mode=edit), and check **step-by-step** that you correctly anticipated what pytutor would display. *If you didn't*, try to understand why you didn't, and what you can do to avoid making the same mistake in the future. **You should also stop at the first mistake you made and reattempt Step 1!**
# 3. Look at the output in pytutor to check that you got the correct answer

# %% [markdown]
# #### 0.0 Tracing some list operations
#
# If the code errors, you can write out "error" for your response

# %% [markdown]
# ```python
# def fun1(x):
#     x.append(1)
#     return x
#
# def fun2(x):
#     x = [2] + x
#     return x
#
# def fun3(x):
#     x = x + [3]
#
# def fun4(x):
#     x[0] = 4
#     return x
#
# x = [0]
#
# x = fun1(x)
# print(x)  # Output 1
#
# x = fun2(x)
# print(x)  # Output 2
#
# x = fun3(x)
# print(x)  # Output 3
#
# x = fun4(x)
# print(x)  # Output 4
# ```

# %% [markdown]
# #### 0.1 Tracing a while loop with a function as the condition

# %% [markdown]
# ```python
# def is_not_zero(n):
#     return n != 0
#
# def loopy(n):
#     while is_not_zero(n):
#         print(n)
#         n -= 1
#     print("Finished")
#
# loopy(3) # Output 1
# loopy(1) # Output 2
# loopy(0) # Output 3
# ```

# %% [markdown]
# #### 0.2 Tracing boolean conditions
#
# I heard you love booleans, so I put a boolean in your boolean.

# %% [markdown]
# ```python
# def tricky_boolean(a, b):
#     if a:
#         if b:
#             print("yay")
#         print("Ay")
#     elif not a and b:
#         print("Bee")
#     else:
#         print("Nay")
#
# tricky_boolean(True, False) # Output 1
# tricky_boolean(False, True) # Output 2
# tricky_boolean(True, True) # Output 3
# tricky_boolean(False, False) # Output 4
# ```

# %% [markdown]
# #### 0.3 Tracing strings 😩 (Hard)
#
# This is a complicated one, but it's definitely good practice!

# %% [markdown]
# ```python
# def fun1(x):
#     print("In fun1", x)
#     return x + "1"
#     if True:
#         print("In fun1", x)
#
# def fun2(x):
#     if x == None:
#         return "2"
#     if x == None:
#         print("yessss")
#     print(x, "In fun2")
#     x = fun1(x + "2")
#     return x
#
# def fun3(x):
#     print("In fun3", x)
#     x = x + "3"
#     # Note: This function doesn't return anything
#
# def fun4(x):
#     print(x, "In fun4")
#     return x + "4"
#
# x = "x"
# print(fun4(fun1(x)))  # Output 1
# print(fun2(fun3(x)))  # Output 2
# fun2(fun3(fun2(fun4(x))))  # Output 3
# print(fun4(fun2(fun3(x))))  # Output 4
# ```

# %% [markdown]
# #### 0.4 Tracing booleans and weird conditionals (Kinda hard) 😇

# %% [markdown]
# ```python
# def func_a(lst):
#     return len(lst) < 3
#
# def func_b(lst):
#     a = 1
#     if len(lst) < 2:
#         return True
#     elif len(lst) == 2:
#         a = 0
#     return a == 0
#
# def tricky(lst):
#     if func_a(lst):
#         print("A")
#     elif func_b(lst):
#         print("B")
#     if not func_a(lst):
#         print("Not A")
#     elif func_b(lst):
#         print("B")
#     else:
#         print("A")
#     print("ok")
#
# tricky([1, 2, 3]) # Output 1
# tricky([1, 2])    # Output 2
# tricky([])        # Output 3
# ```

# %% [markdown]
# #### 0.5 What would python print?
#
# A good one that puts together various concepts like recursion, multi-argument functions, booleans, etc.

# %% [markdown]
# ```python
# def quick_maths(man, free):
#     print(man)
#     if man % 2 == 0 and free:
#         return quick_maths(man + 2, not free)
#     else:
#         man -= 1
#         if man == 3:
#                 print(man)
#     return man
#
# quick_maths(2, True) # Output 1
# print(quick_maths(5, False)) # Output 2
# ```

# %% [markdown]
# #### 0.6 Sum more trayseen

# %% [markdown]
# ```python
# def is_even(x):
#     if x % 2 == 0:
#         print('even')
#     print('odd')
#     return x - 1
#
# def branch(x):
#     if x > 5:
#         print('one')
#     elif x > 0:
#         print('two')
#     if x > 10:
#         print('three')
#     else:
#         print('four')
#     return x + 5
#
# print(is_even(4)) # Output 1
#
# branch(20) # Output 2
#
# print(branch(3)) # Output 3
#
# print(is_even(is_even(5))) # Output 4
#
# branch(branch(3)) # Output 5
# ```

# %% [markdown]
# # 1. Code-Writing
#
# Code writing is strictly harder than filling in the blanks. As long as you can write code for a question, you should be able to solve comparable fill-in-the-blanks questions too.

# %% [markdown]
# #### 1.0 Ascending numbers

# %% [markdown]
# Implement a function `is_ascending`, which takes in a number `n`. `is_ascending` returns `True` if the one's digit of `n` is less than or equal to the ten's digit, and the ten's digit is less than or equal to the hundred's digit, and so on. In other words, the digits of the number going from right to left must be in ascending order.
#
# This is similar to other exercises you might have seen before. You can do this both iteratively or recursively. I'd recommend trying both!

# %%
def is_ascending(n):
    """Returns True if the digits of N are in ascending order.

    Args:
        n: A number

    Returns:
        True if the digits of N are in ascending order, False otherwise.
    """
    "*** YOUR CODE HERE ***"


assert_equal(got=is_ascending(321), want=True) # Expected output: True
assert_equal(got=is_ascending(123), want=False) # Expected output: False
assert_equal(got=is_ascending(4432221), want=True) # Expected output: True
assert_equal(got=is_ascending(5492), want=False) # Expected output: False
assert_equal(got=is_ascending(5420), want=True) # Expected output: True

# %% [markdown]
# #### 1.1 Counting ones

# %% [markdown]
# Implement a function `count_one`, which takes in a number `n`, and returns the number of ones in the digits of `n`.
#
# Again, you can do this both iteratively or recursively. And again, I'd recommend trying out both!
#
# *Hint: there are two ways you can approach this question: using % or str(). You could try both for this too.*

# %%
def count_one(n):
    """Counts the number of 1s in the digits of n

    Args:
        n: A number

    Returns:
        The number of 1s in the digits of n
    """
    "*** YOUR CODE HERE ***"

assert_equal(got=count_one(7007), want=0) # Expected output: 0
assert_equal(got=count_one(123), want=1) # Expected output: 1
assert_equal(got=count_one(161), want=2) # Expected output: 2
assert_equal(got=count_one(1), want=1) # Expected output: 1

# %% [markdown]
# #### 1.2 Total ones

# %% [markdown]
# Implement a function `total_one`, which takes in a number `n`, and returns the number of ones in the digits of all numbers from `1` to `n`.
#
# Again, you can do this both iteratively or recursively. And once again, I'd recommend trying out both!
#
# *Hint: You can use the `count_one` function from above.*

# %%
def total_ones(n):
    """Returns number of 1s in the digits of all numbers from 1 to
    n.

    Args:
        n: A number

    Returns:
        The number of 1s in the digits of all numbers from 1 to n.
    """
    "*** YOUR CODE HERE ***"

assert_equal(got=total_ones(10), want=2) # Expected output: 2
assert_equal(got=total_ones(15), want=8) # Expected output: 8
assert_equal(got=total_ones(21), want=13) # Expected output: 13

# %% [markdown]
# #### 1.3 Password Security (good practice for booleans)

# %% [markdown]
# You're tasked with writing a function `validate_password(password)` in Python. The function should enforce the following password policy:
#
# - The password is at least 8 characters long
# - The password contains at least one uppercase letter
# - The password contains at least one digit
# - The password contains no spaces
#
# **Note:** to solve this problem, you'll need to use the `isupper()`, `isdigit()`, `isspace()` string functions. You will also be using the `and`, `or`, and `not` boolean operators to combine the conditions. Keep in mind the operator precedence and use parentheses when necessary to make the code clear.
#
# This exercise will help strengthen your understanding of boolean logic, `if` statements, string functions, and the `in` keyword.

# %%
def validate_password(password):
    """
    Validate a password according to the following rules:
    - At least 8 characters long
    - Contains at least one uppercase letter
    - Contains at least one digit
    - No spaces

    Parameters:
    password (str): The password to validate.

    Returns:
    bool: True if the password is valid according to the rules, False otherwise.
    """
    "*** YOUR CODE HERE ***"
    pass

assert_equal(got=validate_password("MyPassword123"), want=True)  # Output: True
assert_equal(got=validate_password("mypassword"), want=False)  # Output: False

# %% [markdown]
# #### 1.4 Dictionaries and counting substrings (good practice for dictionaries)

# %% [markdown]
#  Write a function `count_substrings(s, l)` that takes as input a string `s` and a list of strings `l`. The function should count and return how many times each string in `l` appears as a substring in `s`. The function should return a dictionary where the keys are the strings in `l` and the values are the counts of their occurrences in `s`.
#
# For example, for `s = "abcabcabc"` and `l = ["abc", "ca", "xyz"]`, the function should return `{"abc": 3, "ca": 2, "xyz": 0}`.

# %%
def count_substrings(s, l):
    """
    This function counts the number of times each string from a list appears as a substring in a given string.

    Parameters:
    s (str): The string in which to find substrings.
    l (list of str): A list of substrings to find in the string.

    Returns:
    dict: A dictionary where keys are the substrings from the list and values are their counts in the string.
    """
    "*** YOUR CODE HERE ***"

assert_equal(got=count_substrings("abcabcabc", ["abc", "ca", "xyz"]), want={'abc': 3, 'ca': 2, 'xyz': 0})

# %% [markdown]
# #### 1.5 Max concurrent events (good practice for problem-statement reading)

# %% [markdown]
# You're given a list of boolean values (`True` and `False`) that represent a series of events that have taken place. `True` represents a start event and `False` represents an end event. It's guaranteed that each start event has a corresponding end event.
#
# Write a function, `max_concurrent_events(events)`, that returns the maximum number of events that have taken place concurrently.
#
# The list is ordered chronologically, so an event that starts later appears later in the list. It's also guaranteed that the list starts with a True (start event) and ends with a False (end event).
#
# For example, given the list `[True, True, False, True, False, True, False, False]`, your function should return `2`, because at maximum there are 2 events happening at the same time.

# %%
def max_concurrent_events(events):
    """
    This function takes in a list of boolean values representing a series of events
    that have taken place, and returns the maximum number of events that have taken
    place concurrently.

    Args:
        events (List[bool]): A list of boolean values representing events.
            True represents a start event and False represents an end event.
            It's guaranteed that each start event has a corresponding end event.
            The list is ordered chronologically, so an event that starts later
            appears later in the list. It's also guaranteed that the list starts
            with a True (start event) and ends with a False (end event).
    Returns:
        int: The maximum number of events that have taken place concurrently.
    """

    ############# If you want some additional hints (otherwise delete the following) ############
    # You will need a variable to keep track of the current number of concurrent events,
    # and a variable to keep track of the maximum number of concurrent events.
    # Then, you can iterate over the list of events.
    # When you see a True (start event), you should increase the current number of
    # concurrent events. When you see a False (end event), you should decrease it.
    # After each change, you should update the maximum number of concurrent events if necessary.
    #############################################################################################

    ### YOUR CODE HERE ###


assert_equal(got=max_concurrent_events([True, True, False, True, False, True, False, False]), want=2)

# %% [markdown]
# ## A little more practice...
#
# Functions and control [practice problems](https://cs61a.org/study-guide/functions-control/)

# %% [markdown]
# # 2. Recursion
#
# **NOTE: If you haven't done so already, start off by doing questions 1.0, 1.1, and 1.2 in a recursive fashion**
#
# Most of the questions in this section apart from 2.1 are quite challenging

# %% [markdown]
# #### 2.1 Recursion gone wrong

# %% [markdown]
# A factorial of a number `n` is the product of all the numbers from `1` to `n`. For example, the factorial of `5` is `5 * 4 * 3 * 2 * 1 = 120`.
#
# Describe what is wrong with the following `factorial` function and find a way to fix it:

# %%
def factorial(n):
    return n * factorial(n)

# %% [markdown]
# How would you fix it?

# %%
# YOUR EXPLANATION HERE

# %% [markdown]
# #### 2.2 Find SUM (Hard)

# %% [markdown]
# Implement a recursive function `find_sum(n, lst)` that takes an integer `n` and a list of integers `lst` and returns a list of integers from `lst` that add up to `n`. The function should return `None` if no such combination can be found.
#
# **Example:**
# ```python
# >>> find_sum(5, [1, 2, 3, 4])
# [1, 4]
# # 1 + 4 = 5
#
# >>> find_sum(9, [1, 2, 3, 4])
# [2, 3, 4]
# # 2 + 3 + 4 = 9
#
# >>> find_sum(0, [1, 2, 3, 4])
# []
# # empty list is valid as it sums to 0
#
# >>> find_sum(1, [2, 3, 4])
# None
# # No combination can sum to 1
# ```
# **Note:**
# You can assume that `lst` only contains positive integers and does not contain duplicates. You can return any combination of elements that add up to `n`, not necessarily the first one encountered. If there are multiple valid combinations, it's okay to return any one of them.
#
# This problem requires understanding of recursion and list operations in Python. The main challenge is how to iterate through the list recursively and how to accumulate the sum to compare it with `n`.

# %%
def find_sum(n, lst):
    """
    This function takes in a number n and a list of integers lst, and returns a list of integers

    Args:
        n (int): A number
        lst (List[int]): A list of integers

    Returns:
        List[int]: A list of integers from lst that add up to n, or None if no such list exists.
    """
    "*** YOUR CODE HERE ***"

assert_equal(got=find_sum(5, [1, 2, 3, 4]), want=[1, 4])
assert_equal(got=find_sum(9, [1, 2, 3, 4]), want=[2, 3, 4])
assert_equal(got=find_sum(0, [1, 2, 3, 4]), want=[])
assert_equal(got=find_sum(1, [2, 3, 4]), want=None)

# %% [markdown]
# #### 2.3 Towers of Hanoi (Very Hard)

# %% [markdown]
# The Tower of Hanoi is a mathematical puzzle. It consists of three rods and a number of disks of different sizes which can slide onto any rod. The puzzle starts with the disks stacked on one rod in order of size, the smallest at the top, thus forming a conical shape.
#
# The objective of the puzzle is to move the entire stack to another rod, obeying the following rules:
#
# 1. Only one disk can be moved at a time.
# 2. Each move consists of taking the upper disk from one of the stacks and placing it on top of another stack or on an empty rod.
# 3. No disk may be placed on top of a smaller disk.
#
# Write a Python function, `hanoi(n, source, target, auxiliary)`, that prints out the sequence of moves needed to move `n` disks from the `source` rod to the `target` rod using the `auxiliary` rod.
#
# Here, `n` is the number of disks, and `source`, `target`, and `auxiliary` are strings that indicate the rods (for example, they could be "A", "B", and "C").
#
# **Example:**
#
# For example, a call to `hanoi(2, 'A', 'C', 'B')` should print:
# ```
# Move disk 1 from A to B
# Move disk 2 from A to C
# Move disk 1 from B to C
# ```
#
# This problem is a classical example of recursion. To solve it, think about how moving `n` disks can be broken down into sub-problems involving moving `n-1` disks.

# %%
def hanoi(n, source, target, auxiliary):
    """
    This function prints out the steps required to solve the Tower of Hanoi puzzle
    """
    # Base case: when n is 0, there's nothing to do
    if n == 0:
        return
    # Recursive case:

    ################# Optional pseudocode hint ###################################
    # First, think about how to move n-1 disks from the source to the auxiliary rod
    # using the target rod. Then, you'll need to move the nth disk from the source
    # to the target rod. Finally, you'll need to move the n-1 disks from the auxiliary
    # rod to the target rod using the source rod.
    # In each recursive call, remember to decrease n by 1.
    # You'll also need to print out each move in the required format.
    ##############################################################################

    # YOUR CODE HERE


# Now you can test your function with some inputs:
print("Output for hanoi(2, 'A', 'C', 'B'):")
hanoi(2, 'A', 'C', 'B')

# %% [markdown]
# # 3. Time complexity
#
# For the following questions, try to figure out the runtime.

# %% [markdown]
# #### 3.1

# %%
def snippet_one(lst):
    for i in range(len(lst)):
        for j in range(i, len(lst)):
            print(lst[i], lst[j])

# %% [markdown]
# ##### 3.1 Solution

# %%
# @title
# Time complexity: O(n^2)

# This is a nested loop where the number of iterations of the inner loop depends on the current iteration of the outer loop. In the worst case scenario,
# it's roughly equivalent to a full nested loop, which gives us a time complexity of O(n^2).
# The number of operations will be n + (n-1) + (n-2) + (n-3) + ... + 1 (where n is the length of the list). This is approximately equal to n(n+1)/2 (can you figure out why?), which is O(n^2).

# %% [markdown]
# #### 3.2

# %%
def snippet_two(lst):
    for i in range(len(lst)):
        print(lst[i])
    for j in range(len(lst)):
        print(lst[j])

# %% [markdown]
# ##### 3.2 Solution

# %%
# @title
# Time complexity: O(n)

# This code consists of two separate loops that iterate over the list once each.
# This gives a total time complexity of O(n + n), which simplifies to O(n).

# %% [markdown]
# #### 3.3

# %%
def snippet_three(n):
    i = 1
    while i < n:
        i = i * 2

# %% [markdown]
# #### 3.3 Solution

# %%
# @title
# Time complexity: O(log n)

# In this code, the loop variable i doubles during each iteration. Therefore, the number of iterations needed for i to reach n is logarithmic in terms of n.
