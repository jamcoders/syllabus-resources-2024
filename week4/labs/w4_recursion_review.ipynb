# %%
# Always run this code.
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
  # !eval "$(echo "cGlwIGluc3RhbGwgLS1mb3JjZS1yZWluc3RhbGwgZ2l0K2h0dHBzOi8vZ2l0aHViLmNvbS9qYW1jb2RlcnMvamFtY29kZXJzLXB1YmxpYy0yMDI0LmdpdCAtLXF1aWV0Cg==" | base64 -d)"
  # !pip install sympy
  # !pip install numpy
from jamcoders.base_utils import *

# %% [markdown]
# # Week 4 Day 1B Recursion Review
#
# We will be doing more recursion review!

# %% [markdown]
# ## Problem 1
#
# Lets try to calculate powers of a recursively using the following identities.
# 1. $a^0 = 1$
# 2. $a^n = (a^{n-1}) \times a$

# %%
def power(a, n):
    """
    Find's the n-th power of a

    Arguments: a, the base of the exponent, n the power we want to use

    Returns: the nth power of a
    """
    # Your Code Here

assert_equal(want=8, got=power(2, 3))
assert_equal(want=81, got=power(9, 2))
assert_equal(want=27, got=power(3, 3))
assert_equal(want=4, got=power(4, 1))
assert_equal(want=1, got=power(5, 0))

# %% [markdown]
# ## Problem 2
#
# Lets try to find the number of times the integer n appears in our list. Let us use recursion.
#
# Examples:
# ```python
# lst = [1, 2, 10, 0, 10]
# n = 10
# count_n(lst, n) --> 2
#
# lst = [7, 9, 2, 0, 7, 7, 6]
# n = 7
# count_n(lst, n) --> 7
#
# lst = [7, 9, 2, 0, 7, 7, 6]
# n = 3
# count_n(lst, n) --> 0
#
# lst = []
# n = 3
# count_n(lst, n) --> 0
# ```
# *Hint: If the first element is equal to n, then we need to return one plus the number of times the integer appears in lst[1:]*

# %%
def count_n(lst, n):
    """
    Find's the number of times n appears in lst

    Arguments: lst, a list of integers, n, an integer

    Returns: the number of times n appears in lst
    """
    # Your Code Here


assert_equal(want=0, got=count_n([],2))
assert_equal(want=0, got=count_n([0],2))
assert_equal(want=3, got=count_n([2, 5, 2, 6, 2,9],2))
assert_equal(want=1, got=count_n([1, 0, 6, 8, 12],0))
assert_equal(want=50, got=count_n([12 for _ in range(50)], 12))

# %% [markdown]
# ## Problem 3
#
# Let us delete all occurences of a character x with recurstion
#
# Examples:
# ```python
# s = 'hello'
# x = 'e'
# delete(s, x) --> 'hllo'
#
# s = 'eeeee'
# x = 'e'
# delete(s, x) --> ''
#
# s = 'hallo'
# x = 'e'
# delete(s, x) --> 'hallo'
#
# s = 'today'
# x = 'o'
# delete(s, x) --> 'tday'
#
# s = 'hello'
# x = 'l'
# delete(s, x) --> 'heo'
#
# s = ''
# x = 'l'
# delete(s, x) --> ''
# ```

# %%
def delete(s, x):
    """
    Delete all occurences of x in s

    Arguments: s, a string, x, the character we want to delete

    Returns: the resulting string after deletions
    """
    # Your Code Here


assert_equal(want='hllo', got=delete('hello', 'e'))
assert_equal(want='heo', got=delete('hello', 'l'))
assert_equal(want='', got=delete('aaaa', 'a'))
assert_equal(want='', got=delete('', 'a'))
assert_equal(want='nics', got=delete('knicks', 'k'))
assert_equal(want='wow', got=delete('wow', 'k'))
assert_equal(want='o', got=delete('wow', 'w'))
