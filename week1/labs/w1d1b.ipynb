# %% [markdown]
# # Week 1 Day 1, Part B Exercises: Variables, Types, Errors

# %% [markdown]
# ![Reminder to Save](https://i.imgur.com/JFukxlL.png)

# %%
# Always run this code.
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
    # !eval "$(echo "cGlwIGluc3RhbGwgLS1mb3JjZS1yZWluc3RhbGwgZ2l0K2h0dHBzOi8vZ2l0aHViLmNvbS9qYW1jb2RlcnMvamFtY29kZXJzLXB1YmxpYy0yMDI0LmdpdCAtLXF1aWV0Cg==" | base64 -d)"
from jamcoders.week1.week1day1b import *

# %% [markdown]
# # Table of Contents
#
# **[Question 1: Conceptual Recap from Part 1](#1)**
#
# **[Question 2: Types in Python](#2)**
#
# **[Question 3: String Math](#3)**
#
# **[Question 4: Errors](#4)**
#
# **[Question 5: len()](#5)**
#
# **[Question 6: Boolean Operators](#6)**
#
# **[Question 7: Obstacle Course](#7)**
#
# **[Challenge Question: Create Your Own Obstacle Course?](#8)**

# %% [markdown]
# <a name="1"></a>
# ## Question 1: Conceptual Recap from Part 1

# %% [markdown]
# **1.1**
#
# Loosely define the following terms in a comment below, feel free to ask a TA if you want help!
# *   Code
# *   Python
# *   Programming Language
# *   Jupyter Notebook
# *   Algorithm

# %%
# Anything reasonable works

# %% [markdown]
# **1.2**
#
# In lecture, we saw that most algorithms have:
# *   **variables**
# *   **operations** (ex. `+`, `%`, `*`)
# *   **control** (ex. loops, if statements).
#
# What is the purpose of each of these things? What do they do?

# %%
# Anything reasonable works

# %% [markdown]
# <a name="2"></a>
# ## Question 2: Types in Python

# %% [markdown]
# Everything in python has a `type`, and the `type` determines how it gets used by the computer.
#
# First lets see what types look like in Python

# %% [markdown]
# **2.1**
#
# `type(...)` is an important function which we can use to determine the type of anything in python!
#
# Lets use it to figure out the type of the number `1`.

# %%
# This line prints out the type of the number 1
print(type(1))

# %% [markdown]
# **2.2**
#
# Try writing some code that outputs the type of `3.50`

# %%
# YOUR CODE HERE

# %% [markdown]
# **2.3**
#
# Both of these values are numbers.. Why did the different numbers output different types?
#
# Write your answer in a comment below.

# %%
# Your Answer Here

# %% [markdown]
# **2.3**
#
# What is the resulting type of adding ```1``` with ```1```?

# %%
# YOUR CODE HERE

# %% [markdown]
# **2.4**
#
# What is the resulting type of adding ```1``` and ```3.50```?

# %%
# YOUR CODE HERE

# %% [markdown]
# **2.5**
#
# Why did question **2.3** and **2.4** have different outputs? They both are just adding numbers...

# %%
# Your Answer Here

# %% [markdown]
# **2.6**
#
# Similar to before, try comparing the type of these two expressions, and explain the output:
# 1. Print the type of `263 / 34`
# 2. Print the type of `263 // 34`
#
# _Hint: `//` does whole number division_

# %%
# YOUR ANSWER HERE

# %% [markdown]
# **2.7**
#
# So, what can you say about the difference between ints and floats?
#
# *Write the answer in a comment below*

# %%
# YOUR ANSWER HERE

# %% [markdown]
# **2.8**
#
# Lets look at the `type` of strings!
#
# 1. Print the type of `"Hello"`
# 2. Print the type of `"Goodbye"`

# %%
# Your Code Here

# %% [markdown]
# **2.9**
#
# You can also use `type` with variables!
#
# Try running the code below:

# %%
variable_one = 3.5

print("The type of variable_one is:")
print(type(variable_one))

# %%
variable_two = "hello"

print("The type of variable_two is:")
print(type(variable_two))

# %% [markdown]
# **2.10 -- Trick👻👻 Question**
#
# Reggie ran this code to check the type of `"1"`.
#
# Because `1` is a number Reggie knew that the output would say `int`.

# %%
one = "1"

print(type(one))

# %% [markdown]
# Huh?? `<class 'str'>`?
#
# Why didn't it output `int` when `1` is a number?

# %%
# Your Answer Here

# %% [markdown]
# **2.11**
#
# Reggie tried a different number and he got the same output!!
#
# What happened this time?

# %%
three_point_five = 3.5

print(type("three_point_five"))

# %% [markdown]
# Explain your answer below in a comment and write code that does output the type correctly.

# %%
# Your Answer Here

# %% [markdown]
# <a name="3"></a>
# ## Question 3: String Math

# %% [markdown]
# In the questions earlier today, printed `strings` and added and multiplied numbers.
#
# Can we add and multiply strings?
#
# Lets find out!

# %% [markdown]
# **3.1**
#
# What is the result of adding `"Hello"` `+` `"Goodbye"`?
#
# Print out your answer to find out!

# %%
# Your Code Here

# %% [markdown]
# **3.2**
#
# Can you add two different strings so that they have a space between them?

# %%
# Your Code Here

# %% [markdown]
# **3.3**
#
# Now I'm going to give you a challenge!
#
# In the next code block I want you to make the output say `YayYayYayYay`.
#
# But!! Try doing it without typing `"Y"` or `"A"`  ...

# %%
# dont touch the next line
string = "Yay"

# ↓↓ Start coding here ↓↓



# ↑↑ Finish Coding here ↑↑

# Print the text: YayYayYayYay
print(string)

# %% [markdown]
# **3.4**
#
# Lets try multiplying two strings!
#
# Try multiplying `"Hello"` by `"Goodbye"`
#
# Does it work?

# %%
# Your Code Here

# %% [markdown]
# **3.5**
#
# Lets try mixing `type`s!
#
# We know that we can add two strings together, but lets try adding a string with a number!
#
# Try adding `"Hello"` to `5`
#
# Does it work?

# %%
# Your Code Here

# %% [markdown]
# **3.6**
#
# Lets try multiplying strings!
#
# Try multiplying `"Hello"` by `5`
#
# Does it work? Explain in a comment`#` what happened.

# %%
# Your Code Here

# %% [markdown]
# <a name="4"></a>
# ## Question 4: Errors

# %% [markdown]
# The computer is a really hard worker, but sometimes it doesn't know how to do what we tell it. If the computer gets stuck it needs your help!
#
# `Error`s are how the computer tells you what it got confused with. The computer will tell you which line it got confused by, and then it'll say why it got confused by the line.
#
# For example **nobody** can divide by zero, not even calculators or computers. If we tell the computer to run `print(12 / 0)` it'll get confused and tell us it got confused trying to divide by zero.

# %% [markdown]
# **4.1**
#
# The following code works perfectly! Can you change a variable's value so that it makes the computer get stuck?
#
# _Hint: **nobody** and I mean **nobody** can divide by zero_

# %%
# Try changing the numerator
numerator = 12
print("Created the numerator")

# Try changing the denominator
denominator = 6
print("Created the denominator")

print(numerator / denominator)
print("Finished printing numerator/denominator")

# %% [markdown]
# **4.2**
#
# This code works perfectly! Can you change a variable's value so that the computer gets confused and Errors?
#
# _Hint: Review Question 4 type errors_

# %%
# Try changing the predicate
predicate = "Hello"
print("Created the predicate")

# Try changing the subject
subject = " World!"
print("Created the subject")

print(predicate + subject)
print("Finished printing predicate + subject")

# %% [markdown]
# **5.3**
#
# The computer gets confused because I didn't define the variable I'm printing.
#
# Can you fix the error by defining the variable `my_name`?

# %%
# Your Code Here

# Tries to print my_name, but I didn't define it!
print(my_name)

# %% [markdown]
# <a name="5"></a>
# ## Question 5: len()

# %% [markdown]
# **5.1**
#
# Have you ever wondered how many letters that make up one of the longest words in the English dictionary is?
#
# Well, write the code to find the length of the word `"Supercalifragilisticexpialidocious"`

# %%
# Your Code Here

# %% [markdown]
# **5.2**
#
# If we were to break this long word into smaller, more simpler parts, this would be `"super cali fragil is tic ex pi ali do cious "`
#
# Now, what would the length of this string would be? (Let's see if there is a difference now that we have spaces in between and at the end)

# %%
# Your Code Here

# %% [markdown]
# **5.3**
#
# What is the length of `"I am twenty nine letters long"`?

# %%
# Your Code Here

# %% [markdown]
# **5.4**
#
# What happens when you try to find out the length of $10$?
#
# Does it work?

# %%
# Your Code Here

# %% [markdown]
# <a name="6"></a>
# ## Question 6: Boolean Operators

# %% [markdown]
# **6.1**
#
# Values that can be either True or False are called booleans or `bool`s
#
# Try outputting the type of `True` and `False` below

# %%
# Your Code Here
# Note, make sure to capitalize the first letter of True, False

# %% [markdown]
# **6.2**
#
# Boolean Operators take in True/False values (booleans) and return a new True/False value.
#
# Below we have two tables enumerating all inputs/outputs for the Boolean Operators **and** as well as **or**. Tables of this form are called *truth tables*.
#
# These operators, **and** as well as **or**, can both take in two True/False values and return a third True/False value.

# %% [markdown]
# | AND      |  True | False |
# | -------- | ----- | ----- |
# | **True** |   A   |   B   |
# | **False**|   C   |   D   |

# %% [markdown]
# |  OR      |  True | False |
# | -------- | ----- | ----- |
# | **True** |   E   |   F   |
# | **False**|   G   |   H   |

# %% [markdown]
# What are the boolean values of A through H? Use your intuition to fill out the empty list in the text cell below
#
# _Hint: A through H are the values returned by **and** as well as **or**, they can only be **True** or **False**_

# %% [markdown]
# *Fill out this list.*
#
# A [True and True]:
#
# B [True and False]:
#
# C [False and True]:
#
# D [False and False]:
#
# -----------------------------
#
# E [True or True]:
#
# F [True or False]:
#
# G [False or True]:
#
# H [False or False]:

# %% [markdown]
# Use code to check your above answers.

# %%
# For example, try running "print(True and False)".
# Note and, or are all lowercase

# Your Code Here

# %% [markdown]
# A good way to learn this is by learning the operator's personalities!
#
# **and** is _very strict_. They will freak out and answer `False` if **anything** you give them is false. The only way to make them satisfied is by ensuring everything they see is `True`.
#
# **or** is _very friendly_. As long as you give them at least one thing that's true they'll, be happy and output `True`. Be nice though, if everything you give them is false they'll get sad and output `False`.

# %% [markdown]
# **6.3**
#
# Another boolean operator is called **not**. It takes in a single True/False value and returns a new corresponding True/False value.
#
# Try seeing what it outputs for `not True` and `not False`

# %%
# Your Code Here

# %% [markdown]
# **6.4**
#
# One common situation involving booleans is checking for equality and inequality using these operators:
# 1. Equality `==`
# 2. Not Equal `!=`
# 3. Less than `<`
# 4. Less than or Equal to `<=`
# 5. Greater than `>`
# 6. Greater than or equal to `>=`
#
# Below try answering questions using the above operators.

# %%
# Example Question
print_question("Is 1 equal to 2?")
print(1 == 2) # Example Code

print_question("Is 1 equal to 1?")
# Your Code Here

print_question("Is 1 not equal to 2?")
# Your Code Here

print_question("Is 1 less than 2?")
# Your Code Here

print_question("Is 1 less than or equal to 1?")
# Your Code Here

print_question("Is 1 greater than 2?")
# Your Code Here

print_question("Is 1 greater than or equal to 2?")
# Your Code Here

print_question("Is True equal to True?")
# Your Code Here

# %% [markdown]
# **6.5**
#
# Try answering all of the above questions but only using these operators, `not`, as well as `or`
# 1. Equality `==`
# 3. Less than `<`
# 5. Greater than `>`

# %%
print_question("Is 1 less than or equal to 1?")
# Your Code Here

print_question("Is 1 greater than or equal to 2?")
# Your Code Here

print_question("Is 1 not equal to 2?")
# Your Code Here

print_question("Is 1 less than 2 and greater than 0?")
# Your Code Here

# %% [markdown]
# **6.6 Trick👻👻 Question**
#
# Are ```3``` and ```'3'``` equivalent? Use code to confirm (Hint: use `==` to check equivalence).
#
# How about ```True``` and ```'True'```?

# %%
# Your Code Here

# %% [markdown]
# **6.7**
#
# Are ```"Boaz"``` and ```"Boaz"``` equivalent? Use code to confirm.

# %%
# Your Code Here

# %% [markdown]
# **6.8**
#
# Is ```(not False)``` equivalent to ``` True```?

# %%
# Your Code Here

# %% [markdown]
# <a name="7"></a>
# ## Question 7: Obstacle Course

# %% [markdown]
# In this question, you control a variable called `player`. **Your goal is to never print out `False`, and never run into an `Error`.** However, there are some lines that you are not allowed to edit.
#
# In other words, the rules to the game are:
# *   Do not alter any `print` statement
# *   Otherwise, add any code you want, anywhere
# *   Make the code Error free
# *   Pass all levels!

# %%
# Set player to any value you would like!
player = None

print('Level 1 passed?',
      type(player) == str) # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Level 2 passed?',
      type(player) == int and player % 2 == 1) # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Level 3 passed?',
      len(player) == 3) # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Level 4 passed?',
      player == 'secret passcode') # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Level 5 passed?',
      player % 3 == player % 5 == player % 7 and (player > 8)) # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Level 6 passed?',
      player[3] == 'Boaz' and player[0] == player[1]) # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Level 7 passed?',
      type(player) == str and len(player) == 5) # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Level 8 passed?',
      type(player[0]) == list and player[0] + player[1] == player[2] and len(player[2]) > 0) # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Level 9 passed?', len(player) == 2022 and type(player) == str) # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Level 10 passed?', player[2021] == 'jamcoders') # Do not edit this print statement!

# Set player to any value you would like!
player = None

print('Bonus level passed?', type(player) == list and len(player) == 2022 and len(player[0]) == 2022) # Do not edit this print statement!

# %% [markdown]
# <a name="8"></a>
# ## Challenge Question: Create Your Own Obstacle Course **-optional**

# %% [markdown]
# *this question is completely optional! Finish the other questions first, then come back to try it if you have extra time*
#
# Write your own obstacle course, just like we did in question 7! Then, get a friend who has also finished the other exercises, or a TA, to play your obstacle course!
#
# **Please make sure the obstacle course is possible to complete :)**

# %%
# Write your obstacle course here!

# Let the player set the values of the player
player = None

print(True) # Write your obstacles here! The player cannot edit these lines!
