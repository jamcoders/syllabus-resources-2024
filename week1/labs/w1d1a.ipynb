# %% [markdown]
# # Week 1 Day 1, Part A Exercises: Introduction to Python

# %% [markdown]
# ![Reminder to Save](https://i.imgur.com/JFukxlL.png)

# %%
# Always run this code.
# You can run the code by clicking the play button ▶️ to the left or typing `CTRL+ENTER` on your keyboard
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
    # !eval "$(echo "cGlwIGluc3RhbGwgLS1mb3JjZS1yZWluc3RhbGwgZ2l0K2h0dHBzOi8vZ2l0aHViLmNvbS9qYW1jb2RlcnMvamFtY29kZXJzLXB1YmxpYy0yMDI0LmdpdCAtLXF1aWV0Cg==" | base64 -d)"

# %% [markdown]
# ## Instructions
#
# Welcome to Jamcoders! This is a **Jupyter Notebook** with some exercises based on lecture. Jupyter Notebook allows you to write Python code in boxes called **cells** which you can **run** individually (by pressing `CTRL+ENTER`).
#
# The goal of this notebook is to review the following topics:
#
# *   Comments
# *   Math in Python
# *   Printing
# *   Types
# *   Variables

# %% [markdown]
# # Table of Contents
#
# **[Question 1: Welcome to Programming!!!](#1)**
#
# **[Question 2: Doing math with code](#2)**
#
# **[Question 3: Variables](#3)**
#
# **[Question 4: Putting it all together!](#4)**
#
# **[Question 5: Tricky Variable Names](#5)**

# %% [markdown]
# <a name="1"></a>
# ## Question 1: Welcome to Programming!!!

# %% [markdown]
# **1.1**
#
# This is a "text cell." We write text here!
#
# If you click the box you can edit the text inside of it. Click outside of the box to stop editing.

# %% [markdown]
# Try writing your name into this box:
#
# Hi my name is ---, and this is my notebook !

# %% [markdown]
# **1.2**
#
# Now we're going to run our very first piece of code!

# %%
# This is a Code Cell it will run python code when you click the ▶️ button to the left or typing `CTRL+ENTER`
print("Hello world !!!")

# %% [markdown]
# In this code, `"Hello world !!!"` is a `string`. A `string` is a series of characters between two quotation `"` `"` marks.
#
#
# Then, `print("text")` is a very important piece of code which takes in a `string` and makes the program output it. Without the `print`, the text in the program won't leave the code cell.

# %%
"This is a string, but no print is here to let me leave the code cell 😢"
print("This is also a string, the print will send me straight to the output 😀")

# %% [markdown]
# `print` can also send out other things to the output as well like numbers!

# %%
12345 # This won't get sent to output

print(67890) # Only this number will get sent to output !!

54321 # This won't get sent to output

# %% [markdown]
# **1.3**
#
# You can edit the text inside the Code Cell to say whatever you want.
#
# Try making this Code Cell output your favorite color.

# %%
print("My favorite color is ----")

# %% [markdown]
# **1.4**
#
# When we have multiple lines of code, the computer will go through each line one by one.
#
# Try adding a line that prints out your favorite number next to your favorite color

# %%
print("Hello world !!!")
print("My favorite color is ....")
# Your Code Here

print("--------------------------------")

print("Reggie's favorite color is blue")
print("And his favorite number is 16")

# %% [markdown]
# **1.5**
#
# Sometimes its nice to make a computer **not** go through a line of code. Comments let us *hide* a line from the computer. You can turn any line into a comment by putting a `#` character at the start of the line.
#
# We can use a comment to write an explanation for a piece of code that is hidden from the computer!
#
# Write a comment explaining what the second `print` statement does in the cell below.

# %%
# First we output Reggie's favorite color
print("Reggie's favorite color is blue")

print("And his favorite number is 16")

# %% [markdown]
# Reggie HATES it when people say his least favorite color is blue :(
#
# Use comments to correct the output in the cell below.

# %%
print("Reggie's")
print("LEAST")
print("favorite color is blue")

# %% [markdown]
# Congrats on going through the first question of Jamcoders, great work running your first pieces of code🎉🎉

# %% [markdown]
# <a name="2"></a>
# ## Question 2: Doing math with code

# %% [markdown]
# **2.1**
#
# You can do math using symbols like `+` (add), `-` (subtract), `*` (multiply), and `/` (divide).
#
# For example:

# %%
# This next line outputs how many minutes are in two hours
print(2 * 60)

# %% [markdown]
# Try writing some code that outputs what $2500 \times 50$ equals.
#
# Try doing the calculation **only** using the computer.

# %%
# The next line outputs 2500 times 50
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 125000 -->

# %% [markdown]
# **2.2**
#
# Keep in mind that Python does have an order of operations: First Brackets`()`, then Multiplication`*` or Division`/`, and finally Addition`+` or Subtraction`-`.
#
# Write *two* lines of code.
# 1.   In the first line, print out: $335 + 2 \times 6$
# 2.   In the second line, print out: $(335 + 2) \times 6$

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer1: 335 + 2 * 6 = 347 -->
#
# <!-- Answer2: (335 + 2) * 6 = 2022 -->

# %% [markdown]
# In your words, why did the two lines return different values?
#
# *Write your answer below*

# %% [markdown]
# Your Answer Here:
#
# ...

# %% [markdown]
# **2.3**
#
# Let's try solving some word problems!
#
# Xavier noticed cherries growing on a tree. He counted 365 green cherries, 65 red cherries and 45 yellow cherries. Using ONLY code (no pen, paper, or calculator), print how many cherries he counted in total:

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 475 cherries -->

# %% [markdown]
# **2.4**
#
# The next day Xavier noticed that 37 cherries had fallen from the tree. Print how many cherries are left on the tree:

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 438 cherries -->

# %% [markdown]
# **2.5**
#
# Xavier found a type of millipede that has a total of 354 legs beside a rock. When he looked under the rock, he saw 45 of these millipedes underneath. How many legs did Xavier see under the rock in total?

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 15930 legs -->

# %% [markdown]
# **2.6**
#
# Reggie bought 263 cases of soda to give to some clubs for their respective club parties and celebrations. He invited a total of 34 clubs to come and collect the cases of soda at his house. How many cases of soda would each club receive?

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 7.735 cases -->

# %% [markdown]
# **2.7**
#
# Oh no, they didn't divide equally.. Reggie was tired and decided that he'd rather not split up cases of soda for each club. Instead, he will give each club a whole number of soda cases. Write some code that will output how many whole cases will he give each club.
#
# _Hint: Try using `//` instead of `/`. When you use two slashes, you're using **whole number** (or integer) division._

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 7 cases -->

# %% [markdown]
# **2.8**
#
# Reggie went and gave each club their whole number of cases, how many cases does he have left?

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 25 cases -->

# %% [markdown]
# **2.9**
#
# A nice way to think about what we did is that Reggie divided his 263 cases of soda equally among 34 clubs and kept the remainder.
#
# Mathematically we can think about this as $263$ divided by $34$ is $7$ with a remainder of $25$.
#
# Did you know that we can get the remainder of a division in python with one line ??
#
# Instead of doing `263 // 34` try doing `263 % 34` and watch the remainder pop out!

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 25 cases -->

# %% [markdown]
# **2.10**
#
# If I work 40 hours a week, and I work Monday through Friday, how many hours do I work each day?

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 8 hours per day -->

# %% [markdown]
# **2.11**
#
# Next write some code that outputs how many minutes are in two and a half days.

# %%
# Your Code Here

# %% [markdown]
# **Double Click to show answer:**
#
# <!-- Answer: 2160 minutes -->

# %% [markdown]
# <a name="3"></a>
# ## Question 3: Variables

# %% [markdown]
# Variables are like a house for values. In python we give them a name, and can assign them a value, and then can use the variable later on however we like.
#
# Lets try it out!

# %%
# This line **creates** a variable called big_number
# 987654321
big_number = 987654321

# This line prints big_number, 987654321
print(big_number)

# %% [markdown]
# Notice that if we try using a variable *before* its defined, we run into trouble!

# %%
# I never said what humongous_number is!!
print(humongous_number)

# %% [markdown]
# Lets try again by defining our variable before printing it.

# %%
# python remembers big_number because we ran code defining it earlier
huge_number = 100 * big_number

print(huge_number)

# %% [markdown]
# We can also change variables after defining them.

# %%
# Now the number is even more huge !!!
huge_number = huge_number * 9999

print(huge_number)

# %% [markdown]
# Lets try doing some exercises with variables!

# %% [markdown]
# **3.1**
#
# Define a variable ```x``` that has a value of ```5```.

# %%
# YOUR CODE HERE

# %% [markdown]
# **3.2**
#
# Define a variable ```y``` that has a value of ```x```.

# %%
# YOUR CODE HERE

# %% [markdown]
# **3.3**
#
# Use `print` to check the value of ```y```.

# %%
# YOUR CODE HERE

# %% [markdown]
# **3.4**
#
# Change ```x``` to ```4```. What is the value of ```y``` now?

# %%
# YOUR CODE HERE

# %% [markdown]
# **3.5**
#
# Define a variable ```z```, that has a value of the sum of ```x``` and ```y```

# %%
# YOUR CODE HERE

# %% [markdown]
# **3.6**
#
# Assign ```x``` another value, ```12```. What are the values of ```y``` and ```z```?

# %%
# YOUR CODE HERE

# %% [markdown]
# **3.7 - Trick Question👻👻**
#
# Reggie was messing with variables and something mysterious happened...
#
# Run the code cell below with ▶️

# %%
mysterious_variable = 16

print("mysterious_variable")

# %% [markdown]
# Reggie printed `mysterious_variable`, why didn't it show 16???
#
# Explain your answer in a comment below.

# %%
# Your Answer Here

# %% [markdown]
# **3.8**
#
# Can you write a version that makes `mysterious_variable` print out as 16?

# %%
# Your Code Here

# %% [markdown]
# **3.9**
#
# Variables can hold _**ANYTHING!**_ Can you make a variable hold your name and then print it to the screen?

# %%
# Your Code Here

# %% [markdown]
# <a name="4"></a>
# ## Question 4: Putting it all together!

# %% [markdown]
# A nice way to do operations on a variable is to use shorthand operators!
#
# Here's one way to calculate $(10 * 10 + 20) / 5$ step by step

# %%
# Lets start with 10
answer = 10

# Multiply that by another 10
answer = answer * 10

# Add 20 to it
answer = answer + 20

# Then divide it all by 5
answer = answer / 5

print(answer)

# %% [markdown]
# Notice how I kept doing `answer = answer * ...` ?
#
# Instead python lets us do `answer *= ...`, `answer += ...`, and `answer /= ...` !
#
# These are called _short_hand operators because when we type `answer *= x` we're telling the computer to actually do `answer = answer * x `
#
# Like:

# %%
# Lets start with 10
answer = 10

# Multiply the answer by another 10
# answer = answer * 10
answer *= 10

# Add 20 to the answer
# answer = answer + 20
answer += 20

# Then divide the answer by 5
# answer = answer / 5
answer /= 5

# And we get the same answer!
print(answer)

# %% [markdown]
# **4.1**
#
# I want to show you a little trick :)
#
# First, define a variable ```k``` and set it equal to your favorite whole number

# %%
# Your Code Here

# %% [markdown]
# **4.2**
#
# Now multiply `k` by 26 using the `*=` operator

# %%
# Your Code Here

# %% [markdown]
# **4.3**
#
# Now multiply `k` by 585

# %%
# Your Code Here

# %% [markdown]
# **4.4**
#
# Now divide your current `k` by 3 using the `/=` operator

# %%
# Your Code Here

# %% [markdown]
# **4.5**
#
# Subtract 7 from `k` using the `-=` operator

# %%
# Your Code Here

# %% [markdown]
# **4.6**
#
# Calculate the remainder of your number after dividing by 10 using the `%=` operator

# %%
# Your Code Here

# %% [markdown]
# **4.7**
#
# Now let me guess..... does your answer equal `3`? Print the value of `k` to check
#
# (*You may have to re-run run cells **4.1-4.6** each once for this to work*)

# %%
# Your Code Here

# %% [markdown]
# <a name="5"></a>
# ## Question 5: Tricky Variable Names

# %% [markdown]
# So we have been writing code and getting the answers from the computer. Now, let's test to see if you can read a problem and determine the solution without checking with the computer. Here, YOU are the computer...
#
# Suppose you are reading the following code:
# ```python
# seven = 11
# boaz = 'C0der'
# Boaz = 'Jam'
# four = 4
# ten = 16
# ```
# *Without running this code, answer the following questions in text*

# %% [markdown]
# **5.1**
#
# What is the value of the variable ```seven```?

# %% [markdown]
# _Your Answer Here_

# %% [markdown]
# Click to show answer:
#
# 11

# %% [markdown]
# **5.2**
#
# What is the value of the variable `ten` minus the variable `four`?

# %% [markdown]
# _Your Answer Here_

# %% [markdown]
# Click to show answer:
#
# 12

# %% [markdown]
# **5.3**
#
# What would be the output if I ran `print(Boaz)`?

# %% [markdown]
# _Your Answer Here_

# %% [markdown]
# Click to show answer:
#
# The output would be "Jam"

# %% [markdown]
# **Trick👻👻 Question**: What would be the output if I ran `print("boaz")`?

# %% [markdown]
# _Your Answer Here_

# %% [markdown]
# Click to show answer:
#
# The output would be "boaz". This is because we printed the string `"boaz"`, not the variable `boaz` just like exercise 3.7

# %% [markdown]
# # END OF QUESTIONS

# %% [markdown]
# Congratulations on being in your first JamCoders Lab!!
#
# Was this your first time coding? Either way, for all of you, the entire JamCoder's staff would like to congratulate you for working hard, getting to lab, and genuinely doing your best today.
#
# We are all looking forward to getting to know everyone throughout the month. Thank you so much for being here in this program!
